# %% [markdown]
# # **Importing Necessary Lieraries**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# from google.colab import files
# import io
from scipy import stats
from scipy.stats import kendalltau
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.graphics.tsaplots import plot_acf
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
import folium
from folium.plugins import FastMarkerCluster

# %% [markdown]
# # **Loading the datasets**

# %%
data = pd.read_csv('all_yearly.csv')
data2 = pd.read_excel('Weather (1).xlsx')

# %% [markdown]
# **Ensure consistent column names for merging**

# %%
data.rename(columns={'station_id': 'Station ID'}, inplace=True)

# %% [markdown]
# **Merge the datasets on 'Station ID'**

# %%
merged_df = pd.merge(data, data2, on='Station ID')
merged_df
# Out:
#                 Station ID  year  n_rain   R5mm  R10mm  R20mm   SDII  PRCPTOT  \
# 0                  ATHENRY  2012     275    NaN    NaN    NaN    NaN      NaN
# 1                  ATHENRY  2013     365   78.0   33.0    9.0  6.703   1112.7
# 2                  ATHENRY  2014     365   96.0   35.0    5.0  6.468   1235.3
# 3                  ATHENRY  2015     365  116.0   50.0   10.0  7.527   1543.1
# 4                  ATHENRY  2016     366   76.0   23.0    3.0  5.623   1045.8
# ...                    ...   ...     ...    ...    ...    ...    ...      ...
# 1684  VALENTIA OBSERVATORY  2019     365  117.0   59.0   11.0  8.039   1664.0
# 1685  VALENTIA OBSERVATORY  2020     366  124.0   64.0   20.0  9.283   1912.3
# 1686  VALENTIA OBSERVATORY  2021     365  101.0   47.0   17.0  7.700   1524.6
# 1687  VALENTIA OBSERVATORY  2022     365  109.0   60.0   19.0  8.786   1651.7
# 1688  VALENTIA OBSERVATORY  2023     365  124.0   68.0   20.0  8.978   1912.4
#
#        CDD    CWD  ...  TN10p   TN90p  TX10p   TX90p  WSDI  CSDI    GSL  \
# 0      NaN    NaN  ...    NaN     NaN    NaN     NaN   NaN   NaN  328.0
# 1     29.1   87.3  ...    NaN     NaN    NaN     NaN   NaN   NaN  321.0
# 2     31.9   58.1  ...    NaN     NaN    NaN     NaN   NaN   NaN  337.0
# 3     34.5   85.3  ...    NaN     NaN    NaN     NaN   NaN   NaN  353.0
# 4     30.0   59.2  ...    NaN     NaN    NaN     NaN   NaN   NaN  304.0
# ...    ...    ...  ...    ...     ...    ...     ...   ...   ...    ...
# 1684  37.0   84.6  ...  5.479  24.110  4.384   9.041   8.0   0.0  359.0
# 1685  60.6  108.9  ...  4.918  14.208  2.732  12.568  12.0   0.0  360.0
# 1686  61.4   95.8  ...  5.753  20.822  6.027  13.973   6.0   0.0  349.0
# 1687  37.3  108.4  ...  4.670  24.725  4.121  18.956  22.0  10.0  340.0
# 1688  67.8   95.2  ...  1.096  30.959  2.192  18.082  20.0   0.0  359.0
#
#       Latitude  Longitude   Direction
# 0         53.3       -8.8  north-west
# 1         53.3       -8.8  north-west
# 2         53.3       -8.8  north-west
# 3         53.3       -8.8  north-west
# 4         53.3       -8.8  north-west
# ...        ...        ...         ...
# 1684      51.9      -10.2  south-west
# 1685      51.9      -10.2  south-west
# 1686      51.9      -10.2  south-west
# 1687      51.9      -10.2  south-west
# 1688      51.9      -10.2  south-west
#
# [1689 rows x 35 columns]

# %% [markdown]
# **Create a copy of the merged data**set

# %%
merged_df_copy = merged_df.copy()

# %% [markdown]
# # **outliers handling**

# %%
# Define the columns to check for outliers
columns_to_check = [
    'year', 'n_rain', 'R5mm', 'R10mm', 'R20mm', 'SDII', 'PRCPTOT',
    'CDD', 'CWD', 'Rx1day', 'Rx5day', 'R95pTOT', 'R99pTOT', 'n_maxdy',
    'n_mindy', 'FD', 'TR', 'SU', 'ID', 'TNn', 'TNx', 'TXn', 'TXx',
    'DTR', 'TN10p', 'TN90p', 'TX10p', 'TX90p', 'WSDI', 'CSDI', 'GSL'
]

# Initialize a dictionary to store the count of outliers for each column
outlier_counts = {}

for column in columns_to_check:
    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = merged_df_copy[column].quantile(0.25)
    Q3 = merged_df_copy[column].quantile(0.75)
    IQR = Q3 - Q1

    # Define bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Count outliers
    num_outliers = ((merged_df_copy[column] < lower_bound) | (merged_df_copy[column] > upper_bound)).sum()

    # Store the count in the dictionary
    outlier_counts[column] = num_outliers

# Convert the dictionary to a DataFrame for better readability
outlier_counts_df = pd.DataFrame(list(outlier_counts.items()), columns=['Column', 'Outlier Count'])

# Display the DataFrame with outlier counts
print(outlier_counts_df)
# Out:
#      Column  Outlier Count
# 0      year              0
# 1    n_rain            615
# 2      R5mm             32
# 3     R10mm             38
# 4     R20mm             76
# 5      SDII             20
# 6   PRCPTOT             44
# 7       CDD             77
# 8       CWD             53
# 9    Rx1day             25
# 10   Rx5day             48
# 11  R95pTOT             41
# 12  R99pTOT             64
# 13  n_maxdy            497
# 14  n_mindy            505
# 15       FD             12
# 16       TR              1
# 17       SU            121
# 18       ID            241
# 19      TNn             27
# 20      TNx              6
# 21      TXn             21
# 22      TXx             12
# 23      DTR              0
# 24    TN10p             14
# 25    TN90p             10
# 26    TX10p             28
# 27    TX90p             10
# 28     WSDI             24
# 29     CSDI            238
# 30      GSL             45

# %%
# Calculate Q1 (25th percentile) and Q3 (75th percentile)
Q1 = merged_df_copy['PRCPTOT'].quantile(0.25)
Q3 = merged_df_copy['PRCPTOT'].quantile(0.75)
IQR = Q3 - Q1

# Define bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Remove rows where 'PRCPTOT' is an outlier
cleaned_df = merged_df_copy[(merged_df_copy['PRCPTOT'] >= lower_bound) & (merged_df_copy['PRCPTOT'] <= upper_bound)]

# Display the cleaned DataFrame
print(cleaned_df)
# Out:
#                 Station ID  year  n_rain   R5mm  R10mm  R20mm   SDII  PRCPTOT  \
# 1                  ATHENRY  2013     365   78.0   33.0    9.0  6.703   1112.7
# 2                  ATHENRY  2014     365   96.0   35.0    5.0  6.468   1235.3
# 3                  ATHENRY  2015     365  116.0   50.0   10.0  7.527   1543.1
# 4                  ATHENRY  2016     366   76.0   23.0    3.0  5.623   1045.8
# 5                  ATHENRY  2017     365   80.0   33.0    6.0  5.958   1167.8
# ...                    ...   ...     ...    ...    ...    ...    ...      ...
# 1678  VALENTIA OBSERVATORY  2013     365  104.0   52.0   18.0  7.900   1619.4
# 1681  VALENTIA OBSERVATORY  2016     366   93.0   47.0   13.0  7.973   1586.7
# 1682  VALENTIA OBSERVATORY  2017     365   97.0   46.0   13.0  7.313   1557.6
# 1686  VALENTIA OBSERVATORY  2021     365  101.0   47.0   17.0  7.700   1524.6
# 1687  VALENTIA OBSERVATORY  2022     365  109.0   60.0   19.0  8.786   1651.7
#
#         CDD    CWD  ...  TN10p   TN90p   TX10p   TX90p  WSDI  CSDI    GSL  \
# 1      29.1   87.3  ...    NaN     NaN     NaN     NaN   NaN   NaN  321.0
# 2      31.9   58.1  ...    NaN     NaN     NaN     NaN   NaN   NaN  337.0
# 3      34.5   85.3  ...    NaN     NaN     NaN     NaN   NaN   NaN  353.0
# 4      30.0   59.2  ...    NaN     NaN     NaN     NaN   NaN   NaN  304.0
# 5      38.0   62.4  ...    NaN     NaN     NaN     NaN   NaN   NaN  338.0
# ...     ...    ...  ...    ...     ...     ...     ...   ...   ...    ...
# 1678   38.1   91.5  ...  4.932  21.644  11.781  12.329   0.0   0.0  359.0
# 1681  131.6  169.5  ...  5.738  18.579   3.279   9.563   0.0   0.0  360.0
# 1682   44.0   80.4  ...  3.562  21.918   3.562  13.699   0.0   0.0  355.0
# 1686   61.4   95.8  ...  5.753  20.822   6.027  13.973   6.0   0.0  349.0
# 1687   37.3  108.4  ...  4.670  24.725   4.121  18.956  22.0  10.0  340.0
#
#       Latitude  Longitude   Direction
# 1         53.3       -8.8  north-west
# 2         53.3       -8.8  north-west
# 3         53.3       -8.8  north-west
# 4         53.3       -8.8  north-west
# 5         53.3       -8.8  north-west
# ...        ...        ...         ...
# 1678      51.9      -10.2  south-west
# 1681      51.9      -10.2  south-west
# 1682      51.9      -10.2  south-west
# 1686      51.9      -10.2  south-west
# 1687      51.9      -10.2  south-west
#
# [1505 rows x 35 columns]

# %% [markdown]
# # **Unique list of values**

# %%
df_unq_loc = cleaned_df.drop_duplicates(subset=['Station ID','Direction'])
df_unq_loc
# Out:
#                 Station ID  year  n_rain   R5mm  R10mm  R20mm   SDII  PRCPTOT  \
# 1                  ATHENRY  2013     365   78.0   33.0    9.0  6.703   1112.7
# 13              BALLYHAISE  1994     356   80.0   28.0    2.0  5.811   1075.1
# 44               BELMULLET  1957     365   81.0   26.0    6.0  5.688   1086.5
# 112                   BIRR  1955     365   57.0   22.0    1.0  5.825    739.8
# 167               CASEMENT  1954     365   47.0   19.0    2.0  5.394    809.1
# 238            CLAREMORRIS  1944     366   72.0   33.0    8.0  6.147   1063.5
# 318                 CLONES  1950     365   65.0   21.0    4.0  5.499   1006.4
# 381           CORK AIRPORT  1962     365   61.0   31.0   11.0  7.647   1009.4
# 443         DUBLIN AIRPORT  1941     365   47.0   16.0    2.0  5.280    702.3
# 526                DUNSANY  1941     361   52.0   21.0    3.0  6.032    784.1
# 610                 FINNER  2013     365   79.0   26.0    2.0  5.538   1030.1
# 621                GURTEEN  2010     364   49.0   20.0    3.0  5.390    700.7
# 635              JOHNSTOWN  1941     365   71.0   30.0    4.0  6.655    958.3
# 719               KILKENNY  1958     365   70.0   32.0    6.0  6.615   1045.2
# 771          KNOCK AIRPORT  1989     361   88.0   36.0    9.0  6.808   1266.3
# 807              MACE HEAD  2013     365   65.0   28.0    6.0  5.956    953.0
# 818             MALIN HEAD  1957     365   78.0   26.0    7.0  6.110   1075.3
# 885                MARKREE  1941     365   58.0   21.0    3.0  5.121    844.9
# 969             MOORE PARK  1962     360   57.0   25.0    7.0  6.171    851.6
# 1032             MT DILLON  1953     365   50.0   18.0    2.0  5.357    717.8
# 1104             MULLINGAR  1944     366   59.0   26.0    3.0  5.698    911.6
# 1184               NEWPORT  1961     363  110.0   44.0   10.0  7.707   1587.7
# 1248              OAK PARK  1968     366   55.0   20.0    5.0  6.186    798.0
# 1304          PHOENIX PARK  1941     365   45.0   13.0    5.0  4.856    684.7
# 1387          ROCHES POINT  1941     365   74.0   29.0    2.0  6.454    922.9
# 1471              ROSSLARE  1957     365   66.0   31.0    7.0  6.806    980.1
# 1523       SHANNON AIRPORT  1941     365   55.0   17.0    3.0  5.740    780.7
# 1606  VALENTIA OBSERVATORY  1941     365   80.0   41.0   14.0  8.147   1238.4
#
#        CDD    CWD  ...   TN10p   TN90p   TX10p   TX90p  WSDI  CSDI    GSL  \
# 1     29.1   87.3  ...     NaN     NaN     NaN     NaN   NaN   NaN  321.0
# 13    33.0   49.1  ...     NaN     NaN     NaN     NaN   NaN   NaN    NaN
# 44    34.6   56.5  ...   5.753  17.534   5.753  16.986  31.0   0.0  359.0
# 112   21.0   49.6  ...  18.356  12.329  12.603  17.534   6.0  14.0  327.0
# 167   47.4   80.7  ...     NaN     NaN     NaN     NaN   NaN   NaN    NaN
# 238   32.0   56.7  ...     NaN     NaN     NaN     NaN   NaN   NaN    NaN
# 318   62.0   88.9  ...     NaN     NaN     NaN     NaN   NaN   NaN    NaN
# 381   39.2   79.2  ...  16.614   3.816  15.665   5.568   0.0   0.0  335.0
# 443   36.9   61.1  ...     NaN     NaN     NaN     NaN   NaN   NaN    NaN
# 526   44.5   54.4  ...     NaN     NaN     NaN     NaN   NaN   NaN    NaN
# 610   22.8   57.2  ...     NaN     NaN     NaN     NaN   NaN   NaN  359.0
# 621   27.5   61.0  ...     NaN     NaN     NaN     NaN   NaN   NaN  336.0
# 635   37.3   79.6  ...     NaN     NaN     NaN     NaN   NaN   NaN    NaN
# 719   39.0   75.5  ...   8.219  10.411  11.507   6.849   0.0   0.0  319.0
# 771   64.4  127.1  ...     NaN     NaN     NaN     NaN   NaN   NaN    NaN
# 807   26.6   63.8  ...     NaN     NaN     NaN     NaN   NaN   NaN  359.0
# 818   56.0   84.1  ...   4.932  15.068   7.123  12.877   0.0   0.0  358.0
# 885   33.8   82.3  ...     NaN     NaN     NaN     NaN   NaN   NaN    NaN
# 969   33.0   68.7  ...  16.703   3.630  11.487  10.685   0.0   0.0  335.0
# 1032  27.7   73.6  ...     NaN     NaN     NaN     NaN   NaN   NaN    NaN
# 1104  24.0   53.9  ...     NaN     NaN     NaN     NaN   NaN   NaN    NaN
# 1184  69.4  137.2  ...  10.902  10.893   8.418  12.641  15.0   0.0  335.0
# 1248  29.0   50.1  ...  16.976   7.995   5.999  10.299   0.0   0.0  345.0
# 1304  34.1   58.5  ...     NaN     NaN     NaN     NaN   NaN   NaN    NaN
# 1387  28.5   59.3  ...     NaN     NaN     NaN     NaN   NaN   NaN    NaN
# 1471  74.4  142.2  ...   8.767  16.164   4.658  12.055   0.0   0.0  359.0
# 1523  64.6   73.0  ...     NaN     NaN     NaN     NaN   NaN   NaN    NaN
# 1606  45.3   92.8  ...  12.877   9.041  10.685   6.301   0.0   0.0  337.0
#
#       Latitude  Longitude      Direction
# 1         53.3       -8.8     north-west
# 13        54.1       -7.3     north-east
# 44        54.2      -10.0     north-west
# 112       53.1       -7.9     south-east
# 167       53.3       -6.4     north-east
# 238       53.7       -9.0     north-west
# 318       54.2       -7.2     north-east
# 381       51.8       -8.5     south-west
# 443       53.4       -6.2     north-east
# 526       53.5       -6.7     north-east
# 610       54.5       -8.2     north-west
# 621       53.0       -8.0  south-central
# 635       52.3       -6.5     south-east
# 719       52.7       -7.3     south-east
# 771       53.9       -8.8     north-west
# 807       53.3       -9.9     north-west
# 818       55.4       -7.3     north-east
# 885       54.2       -8.5     north-west
# 969       52.2       -8.3     south-west
# 1032      53.7       -8.0  north-central
# 1104      53.5       -7.4     north-east
# 1184      53.9       -9.6     north-west
# 1248      52.9       -6.9     south-east
# 1304      53.4       -6.3     north-east
# 1387      51.8       -8.2     south-west
# 1471      52.2       -6.3     south-east
# 1523      52.7       -8.9     south-west
# 1606      51.9      -10.2     south-west
#
# [28 rows x 35 columns]

# %% [markdown]
# **Add the Precipitation to the graph to understand differences**

# %%
df_s = cleaned_df.groupby(['Station ID'])['PRCPTOT'].agg(['min','mean','max'])
df_s
# Out:
#                          min         mean     max
# Station ID
# ATHENRY               1045.8  1254.136364  1552.7
# BALLYHAISE             723.0   993.152174  1226.6
# BELMULLET              895.4  1167.171642  1490.8
# BIRR                   552.1   798.690741  1084.3
# CASEMENT               541.0   718.733333   992.4
# CLAREMORRIS            826.0  1145.350685  1606.4
# CLONES                 617.9   908.522414  1156.8
# CORK AIRPORT           871.2  1195.754839  1544.4
# DUBLIN AIRPORT         524.4   721.912195  1073.0
# DUNSANY                564.1   818.206667  1024.4
# FINNER                1030.1  1187.940000  1461.9
# GURTEEN                700.7   894.784615  1038.7
# JOHNSTOWN              697.9  1015.254430  1387.7
# KILKENNY               633.2   817.734000  1093.6
# KNOCK AIRPORT         1041.7  1327.581818  1625.0
# MACE HEAD              953.0  1075.454545  1243.7
# MALIN HEAD             812.0  1063.856923  1453.3
# MARKREE                829.5  1160.892063  1510.7
# MOORE PARK             732.0   984.984211  1295.3
# MT DILLON              693.1   947.856818  1309.1
# MULLINGAR              612.7   931.401250  1192.1
# NEWPORT               1147.3  1469.738636  1647.9
# OAK PARK               565.7   776.465116  1088.6
# PHOENIX PARK           547.6   737.703659  1041.3
# ROCHES POINT           658.3   942.750000  1270.8
# ROSSLARE               617.6   873.507843  1231.7
# SHANNON AIRPORT        677.9   932.972289  1239.7
# VALENTIA OBSERVATORY   960.0  1395.087879  1651.7

# %% [markdown]
# **Merge the unique locations and precipitation**

# %%
df_s = df_s.reset_index()
df_unq_temp = pd.merge(df_unq_loc.loc[:,['Station ID','Direction','Latitude','Longitude']],
                       df_s,
                       how='left',
                       on=['Station ID']
                      )
df_unq_temp
# Out:
#               Station ID      Direction  Latitude  Longitude     min  \
# 0                ATHENRY     north-west      53.3       -8.8  1045.8
# 1             BALLYHAISE     north-east      54.1       -7.3   723.0
# 2              BELMULLET     north-west      54.2      -10.0   895.4
# 3                   BIRR     south-east      53.1       -7.9   552.1
# 4               CASEMENT     north-east      53.3       -6.4   541.0
# 5            CLAREMORRIS     north-west      53.7       -9.0   826.0
# 6                 CLONES     north-east      54.2       -7.2   617.9
# 7           CORK AIRPORT     south-west      51.8       -8.5   871.2
# 8         DUBLIN AIRPORT     north-east      53.4       -6.2   524.4
# 9                DUNSANY     north-east      53.5       -6.7   564.1
# 10                FINNER     north-west      54.5       -8.2  1030.1
# 11               GURTEEN  south-central      53.0       -8.0   700.7
# 12             JOHNSTOWN     south-east      52.3       -6.5   697.9
# 13              KILKENNY     south-east      52.7       -7.3   633.2
# 14         KNOCK AIRPORT     north-west      53.9       -8.8  1041.7
# 15             MACE HEAD     north-west      53.3       -9.9   953.0
# 16            MALIN HEAD     north-east      55.4       -7.3   812.0
# 17               MARKREE     north-west      54.2       -8.5   829.5
# 18            MOORE PARK     south-west      52.2       -8.3   732.0
# 19             MT DILLON  north-central      53.7       -8.0   693.1
# 20             MULLINGAR     north-east      53.5       -7.4   612.7
# 21               NEWPORT     north-west      53.9       -9.6  1147.3
# 22              OAK PARK     south-east      52.9       -6.9   565.7
# 23          PHOENIX PARK     north-east      53.4       -6.3   547.6
# 24          ROCHES POINT     south-west      51.8       -8.2   658.3
# 25              ROSSLARE     south-east      52.2       -6.3   617.6
# 26       SHANNON AIRPORT     south-west      52.7       -8.9   677.9
# 27  VALENTIA OBSERVATORY     south-west      51.9      -10.2   960.0
#
#            mean     max
# 0   1254.136364  1552.7
# 1    993.152174  1226.6
# 2   1167.171642  1490.8
# 3    798.690741  1084.3
# 4    718.733333   992.4
# 5   1145.350685  1606.4
# 6    908.522414  1156.8
# 7   1195.754839  1544.4
# 8    721.912195  1073.0
# 9    818.206667  1024.4
# 10  1187.940000  1461.9
# 11   894.784615  1038.7
# 12  1015.254430  1387.7
# 13   817.734000  1093.6
# 14  1327.581818  1625.0
# 15  1075.454545  1243.7
# 16  1063.856923  1453.3
# 17  1160.892063  1510.7
# 18   984.984211  1295.3
# 19   947.856818  1309.1
# 20   931.401250  1192.1
# 21  1469.738636  1647.9
# 22   776.465116  1088.6
# 23   737.703659  1041.3
# 24   942.750000  1270.8
# 25   873.507843  1231.7
# 26   932.972289  1239.7
# 27  1395.087879  1651.7

# %%
df_s = cleaned_df.groupby(['Direction'])['PRCPTOT'].agg(['min','mean','max'])
df_s
# Out:
#                  min         mean     max
# Direction
# north-central  693.1   947.856818  1309.1
# north-east     524.4   843.108092  1453.3
# north-west     826.0  1220.932372  1647.9
# south-central  700.7   894.784615  1038.7
# south-east     552.1   874.216606  1387.7
# south-west     658.3  1081.386471  1651.7

# %% [markdown]
# # **Map of percipitation according to regions**

# %%
# Function to map directions to colors
def direction_to_color(direction):
    color_map = {
        "north-west": "darkblue",
        "north-east": "blue",
        "south-east": "orange",
        "south-west": "red",
        "south-central": "purple",
        "north-central": "green"
    }
    return color_map.get(direction, "gray")  # Default color if direction is not found

# Summary statistics for each direction
direction_stats = {
    "north-central": {"min": 693.1, "mean": 947.856818, "max": 1309.1},
    "north-east": {"min": 524.4, "mean": 843.108092, "max": 1453.3},
    "north-west": {"min": 826.0, "mean": 1220.932372, "max": 1647.9},
    "south-central": {"min": 700.7, "mean": 894.784615, "max": 1038.7},
    "south-east": {"min": 552.1, "mean": 874.216606, "max": 1387.7},
    "south-west": {"min": 658.3, "mean": 1081.386471, "max": 1651.7}
}

Lat = 53.390862
Long = -6.158100

# Assuming df_unq_temp is your DataFrame with Latitude, Longitude, Direction columns
locations = list(zip(df_unq_temp.Latitude, df_unq_temp.Longitude))

map2 = folium.Map(location=[Lat, Long], zoom_start=7)

# Add details to the markers with color based on direction and include precipitation details
for i in range(len(locations)):
    direction = df_unq_temp.iloc[i]['Direction']
    color = direction_to_color(direction)
    stats = direction_stats.get(direction, {"min": "N/A", "mean": "N/A", "max": "N/A"})
    popup_text = (f"Direction: {direction}<br>"
                  f"Mean Precipitation: {stats['mean']}<br>"
                  f"Min Precipitation: {stats['min']}<br>"
                  f"Max Precipitation: {stats['max']}")
    folium.Marker(locations[i],
                  popup=popup_text,
                  icon=folium.Icon(color=color)
                 ).add_to(map2)

# Display the map
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36c25c58e19808a301607b4f1e0783c7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36c25c58e19808a301607b4f1e0783c7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36c25c58e19808a301607b4f1e0783c7 = L.map(
#                 &quot;map_36c25c58e19808a301607b4f1e0783c7&quot;,
#                 {
#                     center: [53.390862, -6.1581],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_865716f2ac6b3d369d50cddc1037cf69 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_865716f2ac6b3d369d50cddc1037cf69.addTo(map_36c25c58e19808a301607b4f1e0783c7);
#
#
#             var marker_d1b0a94f1d34143989a2884ff8c17333 = L.marker(
#                 [53.3, -8.8],
#                 {}
#             ).addTo(map_36c25c58e19808a301607b4f1e0783c7);
#
#
#             var icon_ddd9532935ed3a1b59d5f104fa0e1a2b = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d1b0a94f1d34143989a2884ff8c17333.setIcon(icon_ddd9532935ed3a1b59d5f104fa0e1a2b);
#
#
#         var popup_db5b2f5c3d63e77c47a91d75f02b1ba6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a95820ae161210878084ed958e46016b = $(`&lt;div id=&quot;html_a95820ae161210878084ed958e46016b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Direction: north-west&lt;br&gt;Mean Precipitation: 1220.932372&lt;br&gt;Min Precipitation: 826.0&lt;br&gt;Max Precipitation: 1647.9&lt;/div&gt;`)[0];
#                 popup_db5b2f5c3d63e77c47a91d75f02b1ba6.setContent(html_a95820ae161210878084ed958e46016b);
#
#
#
#         marker_d1b0a94f1d34143989a2884ff8c17333.bindPopup(popup_db5b2f5c3d63e77c47a91d75f02b1ba6)
#         ;
#
#
#
#
#             var marker_bfca4e00cc2bff353ed8c65ee42ef289 = L.marker(
#                 [54.1, -7.3],
#                 {}
#             ).addTo(map_36c25c58e19808a301607b4f1e0783c7);
#
#
#             var icon_03abcc3bc9fa8292a61c206909eee2b9 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_bfca4e00cc2bff353ed8c65ee42ef289.setIcon(icon_03abcc3bc9fa8292a61c206909eee2b9);
#
#
#         var popup_3029357e76c45d7846918740705c3f46 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a3ab0947119da79130c58bd64ce145df = $(`&lt;div id=&quot;html_a3ab0947119da79130c58bd64ce145df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Direction: north-east&lt;br&gt;Mean Precipitation: 843.108092&lt;br&gt;Min Precipitation: 524.4&lt;br&gt;Max Precipitation: 1453.3&lt;/div&gt;`)[0];
#                 popup_3029357e76c45d7846918740705c3f46.setContent(html_a3ab0947119da79130c58bd64ce145df);
#
#
#
#         marker_bfca4e00cc2bff353ed8c65ee42ef289.bindPopup(popup_3029357e76c45d7846918740705c3f46)
#         ;
#
#
#
#
#             var marker_f6cf15c8567043e83e059be7c4334fd0 = L.marker(
#                 [54.2, -10.0],
#                 {}
#             ).addTo(map_36c25c58e19808a301607b4f1e0783c7);
#
#
#             var icon_d8a2119808415dc250ee97a12e8faaf4 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_f6cf15c8567043e83e059be7c4334fd0.setIcon(icon_d8a2119808415dc250ee97a12e8faaf4);
#
#
#         var popup_be3f389183a4e7a133506b3e935fa42d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_6c739d72c1032ee42cbc875f76eb5463 = $(`&lt;div id=&quot;html_6c739d72c1032ee42cbc875f76eb5463&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Direction: north-west&lt;br&gt;Mean Precipitation: 1220.932372&lt;br&gt;Min Precipitation: 826.0&lt;br&gt;Max Precipitation: 1647.9&lt;/div&gt;`)[0];
#                 popup_be3f389183a4e7a133506b3e935fa42d.setContent(html_6c739d72c1032ee42cbc875f76eb5463);
#
#
#
#         marker_f6cf15c8567043e83e059be7c4334fd0.bindPopup(popup_be3f389183a4e7a133506b3e935fa42d)
#         ;
#
#
#
#
#             var marker_7fdc5dddfbba7c189954e61bee774a98 = L.marker(
#                 [53.1, -7.9],

# %% [markdown]
#        "north-west": "darkblue",
#         "north-east": "blue",
#         "south-east": "orange",
#         "south-west": "red",
#         "south-central": "purple",
#         "north-central": "green"

# %%
df_s = cleaned_df.groupby(['Direction'])['TXx'].agg(['min','mean','max'])
df_s
# Out:
#                  min       mean    max
# Direction
# north-central  23.93  28.228182  31.41
# north-east     20.20  25.168403  33.05
# north-west     20.40  25.387328  30.50
# south-central  23.06  26.688462  31.00
# south-east     19.60  25.136546  32.20
# south-west     18.90  25.063583  32.00

# %% [markdown]
#  Minimum Values (Min):
#
#   1. Highest Minimum: The highest minimum value is observed in the north-central direction (23.93).
#     Lowest Minimum: The lowest minimum value is observed in the south-west direction (18.90).
#     Range: The minimum values across directions range from 18.90 to 23.93, indicating variability in the lower limit across directions.
#
# 2. Mean Values:
#
#     Highest Mean: The north-central direction has the highest mean value (28.228182), suggesting it generally experiences higher values compared to other directions.
#     Lowest Mean: The south-west direction has the lowest mean value (25.063583), indicating relatively lower average values.
#     Consistency: The mean values are relatively close, ranging from 25.063583 to 28.228182, suggesting moderate variation across directions.
#
# 3. Maximum Values (Max):
#
#     Highest Maximum: The highest maximum value is observed in the north-east direction (33.05).
#     Lowest Maximum: The lowest maximum value is observed in the north-west direction (30.50).
#     Range: The maximum values range from 30.50 to 33.05, showing a moderate spread in the highest observed values across different directions.
#
# 4. Comparative Analysis:
#
#     North-Central: Exhibits the highest minimum and mean values, indicating a tendency towards consistently higher readings.
#     North-East: Has the highest maximum value, suggesting extreme conditions may occasionally occur in this direction.
#     South-West: Shows the lowest minimum and mean values, indicating generally lower readings in this direction.
#
# 5. General Trends:
#
#     The north-central and south-central directions tend to have higher minimum and mean values, which might suggest more stable conditions in these directions.
#     The north-east and south-east directions show more variability with higher maximum values, indicating possible fluctuations in conditions.
#     The south-west direction consistently has the lowest values, suggesting it might be the least intense in terms of whatever metric is being measured.
#
# 6. Conclusion:
#
#     The data suggests that the north-central direction is the most stable with consistently higher values.
#     The north-east direction shows the most variability, with a broad range between its minimum and maximum values.
#     The south-west direction appears to be the least intense, with the lowest values across the board.

# %% [markdown]
# # **Map of max temperature according to region**

# %%
# Function to map directions to colors
def direction_to_color(direction):
    color_map = {
        "north-west": "darkblue",
        "north-east": "blue",
        "south-east": "orange",
        "south-west": "red",
        "south-central": "purple",
        "north-central": "green"
    }
    return color_map.get(direction, "gray")


direction_stats = {
    "north-central": {"min": 23.93, "mean": 28.228182, "max": 31.41},
    "north-east": {"min": 20.20, "mean": 25.168403, "max": 33.05},
    "north-west": {"min": 20.40, "mean": 25.387328, "max": 30.50},
    "south-central": {"min": 23.06, "mean": 26.688462, "max": 31.00},
    "south-east": {"min": 19.60, "mean": 25.136546, "max": 32.20},
    "south-west": {"min": 18.90, "mean": 25.063583, "max": 32.00}
}

Lat = 53.390862
Long = -6.158100


locations = list(zip(df_unq_temp.Latitude, df_unq_temp.Longitude))

map2 = folium.Map(location=[Lat, Long], zoom_start=7)


for i in range(len(locations)):
    direction = df_unq_temp.iloc[i]['Direction']
    color = direction_to_color(direction)
    stats = direction_stats.get(direction, {"min": "N/A", "mean": "N/A", "max": "N/A"})
    popup_text = (f"Direction: {direction}<br>"
                  f"Mean Precipitation: {stats['mean']}<br>"
                  f"Min Precipitation: {stats['min']}<br>"
                  f"Max Precipitation: {stats['max']}")
    folium.Marker(locations[i],
                  popup=popup_text,
                  icon=folium.Icon(color=color)
                 ).add_to(map2)

# Display the map
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6e25162fb02f3ed830b482b009bf1468 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6e25162fb02f3ed830b482b009bf1468&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6e25162fb02f3ed830b482b009bf1468 = L.map(
#                 &quot;map_6e25162fb02f3ed830b482b009bf1468&quot;,
#                 {
#                     center: [53.390862, -6.1581],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4645120c4ac4d055279d4f7df5a7af9f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4645120c4ac4d055279d4f7df5a7af9f.addTo(map_6e25162fb02f3ed830b482b009bf1468);
#
#
#             var marker_9baa19b15e773da26ea7271a0d6d5883 = L.marker(
#                 [53.3, -8.8],
#                 {}
#             ).addTo(map_6e25162fb02f3ed830b482b009bf1468);
#
#
#             var icon_89b01e72ea6869b53f97ec2b6570a229 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9baa19b15e773da26ea7271a0d6d5883.setIcon(icon_89b01e72ea6869b53f97ec2b6570a229);
#
#
#         var popup_f339aeddfa718ac4f80acc19e08923d5 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f1339b4c4908cb5ccf4b7eb5e517d320 = $(`&lt;div id=&quot;html_f1339b4c4908cb5ccf4b7eb5e517d320&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Direction: north-west&lt;br&gt;Mean Precipitation: 25.387328&lt;br&gt;Min Precipitation: 20.4&lt;br&gt;Max Precipitation: 30.5&lt;/div&gt;`)[0];
#                 popup_f339aeddfa718ac4f80acc19e08923d5.setContent(html_f1339b4c4908cb5ccf4b7eb5e517d320);
#
#
#
#         marker_9baa19b15e773da26ea7271a0d6d5883.bindPopup(popup_f339aeddfa718ac4f80acc19e08923d5)
#         ;
#
#
#
#
#             var marker_ea659f2b8f275455090d354a2858e8c3 = L.marker(
#                 [54.1, -7.3],
#                 {}
#             ).addTo(map_6e25162fb02f3ed830b482b009bf1468);
#
#
#             var icon_cfb2affcc10d6d84e23aa9a03caaa283 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_ea659f2b8f275455090d354a2858e8c3.setIcon(icon_cfb2affcc10d6d84e23aa9a03caaa283);
#
#
#         var popup_1f7ed5e43c0a4c91c458fc790a5b33b1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ebef2f823d0ba7a128b1ed8ca86a7ef5 = $(`&lt;div id=&quot;html_ebef2f823d0ba7a128b1ed8ca86a7ef5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Direction: north-east&lt;br&gt;Mean Precipitation: 25.168403&lt;br&gt;Min Precipitation: 20.2&lt;br&gt;Max Precipitation: 33.05&lt;/div&gt;`)[0];
#                 popup_1f7ed5e43c0a4c91c458fc790a5b33b1.setContent(html_ebef2f823d0ba7a128b1ed8ca86a7ef5);
#
#
#
#         marker_ea659f2b8f275455090d354a2858e8c3.bindPopup(popup_1f7ed5e43c0a4c91c458fc790a5b33b1)
#         ;
#
#
#
#
#             var marker_d78e1fcaa693621196456d5a552e1336 = L.marker(
#                 [54.2, -10.0],
#                 {}
#             ).addTo(map_6e25162fb02f3ed830b482b009bf1468);
#
#
#             var icon_b3f025f6c4efffaaceec0f5d40054366 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d78e1fcaa693621196456d5a552e1336.setIcon(icon_b3f025f6c4efffaaceec0f5d40054366);
#
#
#         var popup_6556d90b39bf08744f45eeb4a44abb3b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_214a4ce90ffe6ad7667119190e15d22f = $(`&lt;div id=&quot;html_214a4ce90ffe6ad7667119190e15d22f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Direction: north-west&lt;br&gt;Mean Precipitation: 25.387328&lt;br&gt;Min Precipitation: 20.4&lt;br&gt;Max Precipitation: 30.5&lt;/div&gt;`)[0];
#                 popup_6556d90b39bf08744f45eeb4a44abb3b.setContent(html_214a4ce90ffe6ad7667119190e15d22f);
#
#
#
#         marker_d78e1fcaa693621196456d5a552e1336.bindPopup(popup_6556d90b39bf08744f45eeb4a44abb3b)
#         ;
#
#
#
#
#             var marker_97588cce2394e594cd74498c2813fa5f = L.marker(
#                 [53.1, -7.9],
#                 {}

# %%
df_t = cleaned_df.groupby(['Station ID'])['TXx'].agg(['min','mean','max'])
df_t
# Out:
#                         min       mean    max
# Station ID
# ATHENRY               22.83  27.349091  30.47
# BALLYHAISE            23.98  26.066842  30.77
# BELMULLET             20.40  24.478657  29.90
# BIRR                  22.60  26.050000  31.20
# CASEMENT              22.80  25.851667  31.90
# CLAREMORRIS           21.50  25.429077  30.50
# CLONES                22.60  25.261404  30.50
# CORK AIRPORT          21.10  24.108065  28.70
# DUBLIN AIRPORT        21.30  24.540741  29.10
# DUNSANY               22.10  25.905854  30.45
# FINNER                23.90  27.012000  29.31
# GURTEEN               23.06  26.688462  31.00
# JOHNSTOWN             21.00  24.082308  28.20
# KILKENNY              23.20  26.306000  31.50
# KNOCK AIRPORT         22.00  25.126923  28.90
# MACE HEAD             20.90  25.320909  29.17
# MALIN HEAD            20.20  23.338462  27.00
# MARKREE               22.30  26.087333  30.00
# MOORE PARK            22.00  25.864600  30.58
# MT DILLON             23.93  28.228182  31.41
# MULLINGAR             22.10  25.685270  30.35
# NEWPORT               20.80  25.550238  29.80
# OAK PARK              23.00  26.850476  32.20
# PHOENIX PARK          22.10  25.800667  33.05
# ROCHES POINT          20.20  23.421176  27.50
# ROSSLARE              19.60  22.686275  26.20
# SHANNON AIRPORT       22.40  26.316667  32.00
# VALENTIA OBSERVATORY  18.90  25.142576  29.80

# %%
df_s = df_s.reset_index()
df_unq_temp = pd.merge(df_unq_loc.loc[:,['Station ID','Direction','Latitude','Longitude']],
                       df_t,
                       how='left',
                       on=['Station ID']
                      )
df_unq_temp
# Out:
#               Station ID      Direction  Latitude  Longitude    min  \
# 0                ATHENRY     north-west      53.3       -8.8  22.83
# 1             BALLYHAISE     north-east      54.1       -7.3  23.98
# 2              BELMULLET     north-west      54.2      -10.0  20.40
# 3                   BIRR     south-east      53.1       -7.9  22.60
# 4               CASEMENT     north-east      53.3       -6.4  22.80
# 5            CLAREMORRIS     north-west      53.7       -9.0  21.50
# 6                 CLONES     north-east      54.2       -7.2  22.60
# 7           CORK AIRPORT     south-west      51.8       -8.5  21.10
# 8         DUBLIN AIRPORT     north-east      53.4       -6.2  21.30
# 9                DUNSANY     north-east      53.5       -6.7  22.10
# 10                FINNER     north-west      54.5       -8.2  23.90
# 11               GURTEEN  south-central      53.0       -8.0  23.06
# 12             JOHNSTOWN     south-east      52.3       -6.5  21.00
# 13              KILKENNY     south-east      52.7       -7.3  23.20
# 14         KNOCK AIRPORT     north-west      53.9       -8.8  22.00
# 15             MACE HEAD     north-west      53.3       -9.9  20.90
# 16            MALIN HEAD     north-east      55.4       -7.3  20.20
# 17               MARKREE     north-west      54.2       -8.5  22.30
# 18            MOORE PARK     south-west      52.2       -8.3  22.00
# 19             MT DILLON  north-central      53.7       -8.0  23.93
# 20             MULLINGAR     north-east      53.5       -7.4  22.10
# 21               NEWPORT     north-west      53.9       -9.6  20.80
# 22              OAK PARK     south-east      52.9       -6.9  23.00
# 23          PHOENIX PARK     north-east      53.4       -6.3  22.10
# 24          ROCHES POINT     south-west      51.8       -8.2  20.20
# 25              ROSSLARE     south-east      52.2       -6.3  19.60
# 26       SHANNON AIRPORT     south-west      52.7       -8.9  22.40
# 27  VALENTIA OBSERVATORY     south-west      51.9      -10.2  18.90
#
#          mean    max
# 0   27.349091  30.47
# 1   26.066842  30.77
# 2   24.478657  29.90
# 3   26.050000  31.20
# 4   25.851667  31.90
# 5   25.429077  30.50
# 6   25.261404  30.50
# 7   24.108065  28.70
# 8   24.540741  29.10
# 9   25.905854  30.45
# 10  27.012000  29.31
# 11  26.688462  31.00
# 12  24.082308  28.20
# 13  26.306000  31.50
# 14  25.126923  28.90
# 15  25.320909  29.17
# 16  23.338462  27.00
# 17  26.087333  30.00
# 18  25.864600  30.58
# 19  28.228182  31.41
# 20  25.685270  30.35
# 21  25.550238  29.80
# 22  26.850476  32.20
# 23  25.800667  33.05
# 24  23.421176  27.50
# 25  22.686275  26.20
# 26  26.316667  32.00
# 27  25.142576  29.80

# %%
# Function to map directions to colors
def direction_to_color(direction):
    color_map = {
        "north-west": "darkblue",
        "north-east": "blue",
        "south-east": "orange",
        "south-west": "red",
        "south-central": "purple",
        "north-central": "green"
    }
    return color_map.get(direction, "gray") 


direction_stats = {
    "north-central": {"min": 23.93, "mean": 28.228182, "max": 31.41},
    "north-east": {"min": 20.20, "mean": 25.168403, "max": 33.05},
    "north-west": {"min": 20.40, "mean": 25.387328, "max": 30.50},
    "south-central": {"min": 23.06, "mean": 26.688462, "max": 31.00},
    "south-east": {"min": 19.60, "mean": 25.136546, "max": 32.20},
    "south-west": {"min": 18.90, "mean": 25.063583, "max": 32.00}
}

Lat = 53.390862
Long = -6.158100


locations = list(zip(df_unq_temp.Latitude, df_unq_temp.Longitude))

map2 = folium.Map(location=[Lat, Long], zoom_start=7)


for i in range(len(locations)):
    direction = df_unq_temp.iloc[i]['Direction']
    color = direction_to_color(direction)
    stats = direction_stats.get(direction, {"min": "N/A", "mean": "N/A", "max": "N/A"})
    popup_text = (f"Direction: {direction}<br>"
                  f"Mean TXx: {stats['mean']}<br>"
                  f"Min TXx: {stats['min']}<br>"
                  f"Max TXx: {stats['max']}")
    folium.Marker(locations[i],
                  popup=popup_text,
                  icon=folium.Icon(color=color)
                 ).add_to(map2)

# Display the map
map2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_efd86e9c34dc39e725cd961949834f76 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_efd86e9c34dc39e725cd961949834f76&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_efd86e9c34dc39e725cd961949834f76 = L.map(
#                 &quot;map_efd86e9c34dc39e725cd961949834f76&quot;,
#                 {
#                     center: [53.390862, -6.1581],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 7,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4186483c7def7490778a1973f005e522 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_4186483c7def7490778a1973f005e522.addTo(map_efd86e9c34dc39e725cd961949834f76);
#
#
#             var marker_15c7ec7cc1acf0fa9d0eef12849c537f = L.marker(
#                 [53.3, -8.8],
#                 {}
#             ).addTo(map_efd86e9c34dc39e725cd961949834f76);
#
#
#             var icon_45e6e79e04f19431b820aab520523a62 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_15c7ec7cc1acf0fa9d0eef12849c537f.setIcon(icon_45e6e79e04f19431b820aab520523a62);
#
#
#         var popup_7872681969859126a18453e498e54725 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_81d763ef9c9202a03f7946e8c163afad = $(`&lt;div id=&quot;html_81d763ef9c9202a03f7946e8c163afad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Direction: north-west&lt;br&gt;Mean TXx: 25.387328&lt;br&gt;Min TXx: 20.4&lt;br&gt;Max TXx: 30.5&lt;/div&gt;`)[0];
#                 popup_7872681969859126a18453e498e54725.setContent(html_81d763ef9c9202a03f7946e8c163afad);
#
#
#
#         marker_15c7ec7cc1acf0fa9d0eef12849c537f.bindPopup(popup_7872681969859126a18453e498e54725)
#         ;
#
#
#
#
#             var marker_8386b92910203435d0226340f9616269 = L.marker(
#                 [54.1, -7.3],
#                 {}
#             ).addTo(map_efd86e9c34dc39e725cd961949834f76);
#
#
#             var icon_b28703b79f295b8bdd2494b14af7f1e5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;blue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_8386b92910203435d0226340f9616269.setIcon(icon_b28703b79f295b8bdd2494b14af7f1e5);
#
#
#         var popup_881e05dee83fe52c699da9f1f3778f0d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3c33ec817e86710424710453d0ef73d3 = $(`&lt;div id=&quot;html_3c33ec817e86710424710453d0ef73d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Direction: north-east&lt;br&gt;Mean TXx: 25.168403&lt;br&gt;Min TXx: 20.2&lt;br&gt;Max TXx: 33.05&lt;/div&gt;`)[0];
#                 popup_881e05dee83fe52c699da9f1f3778f0d.setContent(html_3c33ec817e86710424710453d0ef73d3);
#
#
#
#         marker_8386b92910203435d0226340f9616269.bindPopup(popup_881e05dee83fe52c699da9f1f3778f0d)
#         ;
#
#
#
#
#             var marker_9219bc03421e6824b3508a5ea8dcb373 = L.marker(
#                 [54.2, -10.0],
#                 {}
#             ).addTo(map_efd86e9c34dc39e725cd961949834f76);
#
#
#             var icon_4903da192429323b70177da6eda6dd67 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;darkblue&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9219bc03421e6824b3508a5ea8dcb373.setIcon(icon_4903da192429323b70177da6eda6dd67);
#
#
#         var popup_6a58df9b5c226959417d6177faabf1b3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1beda2f7c4ded2d9ec5cae72ac21d4e0 = $(`&lt;div id=&quot;html_1beda2f7c4ded2d9ec5cae72ac21d4e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Direction: north-west&lt;br&gt;Mean TXx: 25.387328&lt;br&gt;Min TXx: 20.4&lt;br&gt;Max TXx: 30.5&lt;/div&gt;`)[0];
#                 popup_6a58df9b5c226959417d6177faabf1b3.setContent(html_1beda2f7c4ded2d9ec5cae72ac21d4e0);
#
#
#
#         marker_9219bc03421e6824b3508a5ea8dcb373.bindPopup(popup_6a58df9b5c226959417d6177faabf1b3)
#         ;
#
#
#
#
#             var marker_4ce5397b2065f65fe58109103517707c = L.marker(
#                 [53.1, -7.9],
#                 {}
#             ).addTo(map_efd86e9c34dc39e725cd961949834f76);
#
#
#             var ic

# %% [markdown]
#         "north-west": "darkblue",
#         "north-east": "blue",
#         "south-east": "orange",
#         "south-west": "red",
#         "south-central": "purple",
#         "north-central": "green"
